# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharmiladevi33/Sharmiladevi/blob/main/thyroidnew_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer, Dense, Dropout
path="/content/thyroidDF (1).csv"
data=pd.read_csv(path)
data.head(5)
# Out:
#    age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick pregnant  \
# 0   29   F            f                  f                   f    f        f
# 1   29   F            f                  f                   f    f        f
# 2   41   F            f                  f                   f    f        f
# 3   36   F            f                  f                   f    f        f
# 4   32   F            f                  f                   f    f        f
#
#   thyroid_surgery I131_treatment query_hypothyroid  ...    TT4 T4U_measured  \
# 0               f              f                 t  ...    NaN            f
# 1               f              f                 f  ...  128.0            f
# 2               f              f                 f  ...    NaN            f
# 3               f              f                 f  ...    NaN            f
# 4               f              f                 f  ...    NaN            f
#
#   T4U FTI_measured FTI TBG_measured   TBG  referral_source target  patient_id
# 0 NaN            f NaN            f   NaN            other      -   840801013
# 1 NaN            f NaN            f   NaN            other      -   840801014
# 2 NaN            f NaN            t  11.0            other      -   840801042
# 3 NaN            f NaN            t  26.0            other      -   840803046
# 4 NaN            f NaN            t  36.0            other      S   840803047
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (9172, 31)

# %%
data.isnull().sum()
# Out:
# age                       0
# sex                     307
# on_thyroxine              0
# query_on_thyroxine        0
# on_antithyroid_meds       0
# sick                      0
# pregnant                  0
# thyroid_surgery           0
# I131_treatment            0
# query_hypothyroid         0
# query_hyperthyroid        0
# lithium                   0
# goitre                    0
# tumor                     0
# hypopituitary             0
# psych                     0
# TSH_measured              0
# TSH                     842
# T3_measured               0
# T3                     2604
# TT4_measured              0
# TT4                     442
# T4U_measured              0
# T4U                     809
# FTI_measured              0
# FTI                     802
# TBG_measured              0
# TBG                    8823
# referral_source           0
# target                    0
# patient_id                0
# dtype: int64

# %%
data.drop(['TSH_measured','T3_measured','TT4_measured','T4U_measured','FTI_measured','TBG_measured','referral_source','patient_id',axis=1,inplace=True])
# Out:
#   File "<ipython-input-7-3b5e64e11a98>", line 1
#     data.drop(['TSH_measured','T3_measured','TT4_measured','T4U_measured','FTI_measured','TBG_measured','referral_source','patient_id',axis=1,inplace=True])
#                                                                                                                                            ^
# SyntaxError: invalid syntax

# %%
diagnoses = {'A':'hyperthyroid conditions',
             'B':'hyperthyroid conditions',
             'C':'hyperthyroid conditions',
             'D':'hyperthyroid conditions',
             'E':'hyperthyroid conditions',
             'F':'hyperthyroid conditions',
             'G':'hyperthyroid conditions',
             'H':'hyperthyroid conditions',
             'I':'binding protein',
             'J':'binding protein',
             'K':'genral health',
             'L':'replacement therapy',
             'M':'replacement therapy',
             'N':'replacement therapy',
             'O':'antithyroid treatment',
             'P':'antithyroid treatment',
             'Q':'antithyroid treatment',
             'R':'miscellaneous',
             's':'miscellaneous',
             'T':'miscellaneous'}

# %%
data['target']=data['target'].map(diagnoses)

# %%
data.dropna(subset=['target'],inplace=True)
data['target'].value_counts()
# Out:
# hyperthyroid conditions    775
# genral health              436
# binding protein            376
# replacement therapy        336
# miscellaneous              196
# antithyroid treatment       33
# Name: target, dtype: int64

# %%
data[data.age>100]
# Out:
# Empty DataFrame
# Columns: [age, sex, on_thyroxine, query_on_thyroxine, on_antithyroid_meds, sick, pregnant, thyroid_surgery, I131_treatment, query_hypothyroid, query_hyperthyroid, lithium, goitre, tumor, hypopituitary, psych, TSH_measured, TSH, T3_measured, T3, TT4_measured, TT4, T4U_measured, T4U, FTI_measured, FTI, TBG_measured, TBG, referral_source, target, patient_id]
# Index: []
#
# [0 rows x 31 columns]

# %%
x=data.iloc[:,0:-1]
y=data.iloc[:,-1]
x
# Out:
#       age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 18     63   F            t                  f                   f    t
# 32     41   M            f                  f                   f    f
# 33     71   F            t                  f                   f    f
# 39     55   F            t                  f                   f    f
# 40     32   F            t                  f                   f    f
# ...   ...  ..          ...                ...                 ...  ...
# 9153   64   M            f                  f                   f    f
# 9157   60   M            f                  f                   t    f
# 9158   64   M            f                  f                   f    f
# 9162   36   F            f                  f                   f    f
# 9169   69   M            f                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...  \
# 18          f               f              f                 f  ...
# 32          f               f              f                 f  ...
# 33          f               f              f                 f  ...
# 39          f               f              f                 t  ...
# 40          f               f              f                 f  ...
# ...       ...             ...            ...               ...  ...
# 9153        f               f              f                 f  ...
# 9157        f               f              f                 f  ...
# 9158        f               f              f                 t  ...
# 9162        f               f              f                 f  ...
# 9169        f               f              f                 f  ...
#
#      TT4_measured    TT4 T4U_measured   T4U FTI_measured    FTI TBG_measured  \
# 18              t   48.0            t  1.02            t   47.0            f
# 32              t   39.0            t  1.00            t   39.0            f
# 33              t  126.0            t  1.38            t   91.0            f
# 39              t  136.0            t  1.48            t   92.0            f
# 40              t  163.0            t  0.94            t  173.0            f
# ...           ...    ...          ...   ...          ...    ...          ...
# 9153            t   31.0            t  0.55            t   56.0            f
# 9157            t   28.0            t  0.87            t   32.0            f
# 9158            t   44.0            t  0.53            t   83.0            f
# 9162            t   84.0            t  1.26            t   67.0            f
# 9169            t  113.0            t  1.27            t   89.0            f
#
#       TBG referral_source                   target
# 18    NaN           other  hyperthyroid conditions
# 32    NaN           other            miscellaneous
# 33    NaN           other          binding protein
# 39    NaN           other      replacement therapy
# 40    NaN           other      replacement therapy
# ...   ...             ...                      ...
# 9153  NaN             SVI            genral health
# 9157  NaN           other            genral health
# 9158  NaN           other          binding protein
# 9162  NaN           other          binding protein
# 9169  NaN             SVI          binding protein
#
# [2152 rows x 30 columns]

# %%
x['sex'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
x['sex'].replace(np.nan, 'F',inplace=True)
x['sex'].value_counts()
# Out:
# F    1618
# M     534
# Name: sex, dtype: int64

# %%
x['age']=x['age'].astype('float')
x['TSH']=x['TSH'].astype('float')
x['T3']=x['T3'].astype('float')
x['TT4']=x['TT4'].astype('float')
x['FTI']=x['FTI'].astype('float')
x['TBG']=x['TBG'].astype('float')

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2152 entries, 18 to 9169
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  2152 non-null   float64
#  1   sex                  2152 non-null   object
#  2   on_thyroxine         2152 non-null   object
#  3   query_on_thyroxine   2152 non-null   object
#  4   on_antithyroid_meds  2152 non-null   object
#  5   sick                 2152 non-null   object
#  6   pregnant             2152 non-null   object
#  7   thyroid_surgery      2152 non-null   object
#  8   I131_treatment       2152 non-null   object
#  9   query_hypothyroid    2152 non-null   object
#  10  query_hyperthyroid   2152 non-null   object
#  11  lithium              2152 non-null   object
#  12  goitre               2152 non-null   object
#  13  tumor                2152 non-null   object
#  14  hypopituitary        2152 non-null   object
#  15  psych                2152 non-null   object
#  16  TSH_measured         2152 non-null   object
#  17  TSH                  2087 non-null   float64
#  18  T3_measured          2152 non-null   object
#  19  T3                   1643 non-null   float64
#  20  TT4_measured         2152 non-null   object
#  21  TT4                  2140 non-null   float64
#  22  T4U_measured         2152 non-null   object
#  23  T4U                  2059 non-null   float64
#  24  FTI_measured         2152 non-null   object
#  25  FTI                  2060 non-null   float64
#  26  TBG_measured         2152 non-null   object
#  27  TBG                  13 non-null     float64
#  28  referral_source      2152 non-null   object
#  29  target               2152 non-null   object
# dtypes: float64(7), object(23)
# memory usage: 521.2+ KB

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

ordinal_encoder = OrdinalEncoder(dtype = 'int64')
x.iloc[:, 1:16] = ordinal_encoder.fit_transform(x.iloc[:, 1:16])
x
# Out:
#        age  sex  on_thyroxine  query_on_thyroxine  on_antithyroid_meds  sick  \
# 18    63.0    0             1                   0                    0     1
# 32    41.0    1             0                   0                    0     0
# 33    71.0    0             1                   0                    0     0
# 39    55.0    0             1                   0                    0     0
# 40    32.0    0             1                   0                    0     0
# ...    ...  ...           ...                 ...                  ...   ...
# 9153  64.0    1             0                   0                    0     0
# 9157  60.0    1             0                   0                    1     0
# 9158  64.0    1             0                   0                    0     0
# 9162  36.0    0             0                   0                    0     0
# 9169  69.0    1             0                   0                    0     0
#
#       pregnant  thyroid_surgery  I131_treatment  query_hypothyroid  ...  \
# 18           0                0               0                  0  ...
# 32           0                0               0                  0  ...
# 33           0                0               0                  0  ...
# 39           0                0               0                  1  ...
# 40           0                0               0                  0  ...
# ...        ...              ...             ...                ...  ...
# 9153         0                0               0                  0  ...
# 9157         0                0               0                  0  ...
# 9158         0                0               0                  1  ...
# 9162         0                0               0                  0  ...
# 9169         0                0               0                  0  ...
#
#       TT4_measured    TT4  T4U_measured   T4U  FTI_measured    FTI  \
# 18               t   48.0             t  1.02             t   47.0
# 32               t   39.0             t  1.00             t   39.0
# 33               t  126.0             t  1.38             t   91.0
# 39               t  136.0             t  1.48             t   92.0
# 40               t  163.0             t  0.94             t  173.0
# ...            ...    ...           ...   ...           ...    ...
# 9153             t   31.0             t  0.55             t   56.0
# 9157             t   28.0             t  0.87             t   32.0
# 9158             t   44.0             t  0.53             t   83.0
# 9162             t   84.0             t  1.26             t   67.0
# 9169             t  113.0             t  1.27             t   89.0
#
#      TBG_measured  TBG referral_source                   target
# 18              f  NaN           other  hyperthyroid conditions
# 32              f  NaN           other            miscellaneous
# 33              f  NaN           other          binding protein
# 39              f  NaN           other      replacement therapy
# 40              f  NaN           other      replacement therapy
# ...           ...  ...             ...                      ...
# 9153            f  NaN             SVI            genral health
# 9157            f  NaN           other            genral health
# 9158            f  NaN           other          binding protein
# 9162            f  NaN           other          binding protein
# 9169            f  NaN             SVI          binding protein
#
# [2152 rows x 30 columns]

# %%
x.replace(np.nan,'0',inplace=True)
x
# Out:
#        age  sex  on_thyroxine  query_on_thyroxine  on_antithyroid_meds  sick  \
# 18    63.0    0             1                   0                    0     1
# 32    41.0    1             0                   0                    0     0
# 33    71.0    0             1                   0                    0     0
# 39    55.0    0             1                   0                    0     0
# 40    32.0    0             1                   0                    0     0
# ...    ...  ...           ...                 ...                  ...   ...
# 9153  64.0    1             0                   0                    0     0
# 9157  60.0    1             0                   0                    1     0
# 9158  64.0    1             0                   0                    0     0
# 9162  36.0    0             0                   0                    0     0
# 9169  69.0    1             0                   0                    0     0
#
#       pregnant  thyroid_surgery  I131_treatment  query_hypothyroid  ...  \
# 18           0                0               0                  0  ...
# 32           0                0               0                  0  ...
# 33           0                0               0                  0  ...
# 39           0                0               0                  1  ...
# 40           0                0               0                  0  ...
# ...        ...              ...             ...                ...  ...
# 9153         0                0               0                  0  ...
# 9157         0                0               0                  0  ...
# 9158         0                0               0                  1  ...
# 9162         0                0               0                  0  ...
# 9169         0                0               0                  0  ...
#
#       TT4_measured    TT4  T4U_measured   T4U  FTI_measured    FTI  \
# 18               t   48.0             t  1.02             t   47.0
# 32               t   39.0             t   1.0             t   39.0
# 33               t  126.0             t  1.38             t   91.0
# 39               t  136.0             t  1.48             t   92.0
# 40               t  163.0             t  0.94             t  173.0
# ...            ...    ...           ...   ...           ...    ...
# 9153             t   31.0             t  0.55             t   56.0
# 9157             t   28.0             t  0.87             t   32.0
# 9158             t   44.0             t  0.53             t   83.0
# 9162             t   84.0             t  1.26             t   67.0
# 9169             t  113.0             t  1.27             t   89.0
#
#      TBG_measured TBG referral_source                   target
# 18              f   0           other  hyperthyroid conditions
# 32              f   0           other            miscellaneous
# 33              f   0           other          binding protein
# 39              f   0           other      replacement therapy
# 40              f   0           other      replacement therapy
# ...           ...  ..             ...                      ...
# 9153            f   0             SVI            genral health
# 9157            f   0           other            genral health
# 9158            f   0           other          binding protein
# 9162            f   0           other          binding protein
# 9169            f   0             SVI          binding protein
#
# [2152 rows x 30 columns]

# %%
label_encoder= LabelEncoder()
y_dt= label_encoder.fit_transform(y)

# %%
y=pd.DataFrame(y_dt,columns=['target'])
y
# Out:
#       target
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 2147    2147
# 2148    2148
# 2149    2149
# 2150    2150
# 2151    2151
#
# [2152 rows x 1 columns]

# %%
x=data.iloc[:,0:-1]
y=data.iloc[:,-1]
x
# Out:
#       age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 18     63   F            t                  f                   f    t
# 32     41   M            f                  f                   f    f
# 33     71   F            t                  f                   f    f
# 39     55   F            t                  f                   f    f
# 40     32   F            t                  f                   f    f
# ...   ...  ..          ...                ...                 ...  ...
# 9153   64   M            f                  f                   f    f
# 9157   60   M            f                  f                   t    f
# 9158   64   M            f                  f                   f    f
# 9162   36   F            f                  f                   f    f
# 9169   69   M            f                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...  \
# 18          f               f              f                 f  ...
# 32          f               f              f                 f  ...
# 33          f               f              f                 f  ...
# 39          f               f              f                 t  ...
# 40          f               f              f                 f  ...
# ...       ...             ...            ...               ...  ...
# 9153        f               f              f                 f  ...
# 9157        f               f              f                 f  ...
# 9158        f               f              f                 t  ...
# 9162        f               f              f                 f  ...
# 9169        f               f              f                 f  ...
#
#      TT4_measured    TT4 T4U_measured   T4U FTI_measured    FTI TBG_measured  \
# 18              t   48.0            t  1.02            t   47.0            f
# 32              t   39.0            t  1.00            t   39.0            f
# 33              t  126.0            t  1.38            t   91.0            f
# 39              t  136.0            t  1.48            t   92.0            f
# 40              t  163.0            t  0.94            t  173.0            f
# ...           ...    ...          ...   ...          ...    ...          ...
# 9153            t   31.0            t  0.55            t   56.0            f
# 9157            t   28.0            t  0.87            t   32.0            f
# 9158            t   44.0            t  0.53            t   83.0            f
# 9162            t   84.0            t  1.26            t   67.0            f
# 9169            t  113.0            t  1.27            t   89.0            f
#
#       TBG referral_source                   target
# 18    NaN           other  hyperthyroid conditions
# 32    NaN           other            miscellaneous
# 33    NaN           other          binding protein
# 39    NaN           other      replacement therapy
# 40    NaN           other      replacement therapy
# ...   ...             ...                      ...
# 9153  NaN             SVI            genral health
# 9157  NaN           other            genral health
# 9158  NaN           other          binding protein
# 9162  NaN           other          binding protein
# 9169  NaN             SVI          binding protein
#
# [2152 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from imblearn.over_sampling import SMOTE
y_train.value_counts()
# Out:
# 861208030    1
# 851211060    1
# 860306053    1
# 851001014    1
# 850307058    1
#             ..
# 860930021    1
# 861124001    1
# 841016030    1
# 841105011    1
# 860729012    1
# Name: patient_id, Length: 1721, dtype: int64

# %%
os=SMOTE(random_state=0,k_neighbors=1)
x_bal,y_bal=os.fit_resample(x_train,y_train)
x_test_bal,y_test_bal=os.fit_resample(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5837100947c9> in <module>
#       1 os=SMOTE(random_state=0,k_neighbors=1)
# ----> 2 x_bal,y_bal=os.fit_resample(x_train,y_train)
#       3 x_test_bal,y_test_bal=os.fit_resample(x_test,y_test)
#
# /usr/local/lib/python3.9/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# /usr/local/lib/python3.9/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      80         check_classification_targets(y)
#      81         arrays_transformer = ArraysTransformer(X, y)
# ---> 82         X, y, binarize_y = self._check_X_y(X, y)
#      83
#      84         self.sampling_strategy_ = check_sampling_strategy(
#
# /usr/local/lib/python3.9/dist-packages/imblearn/base.py in _check_X_y(self, X, y, accept_sparse)
#     154             accept_sparse = ["csr", "csc"]
#     155         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 156         X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
#     157         return X, y, binarize_y
#     158
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# ValueError: could not convert string to float: 'F'

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_bal=sc.fit_transform(x_bal)
x_test_bal=sc.transform(x_test_bal)
x_bal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-cc96242c0c6d> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc=StandardScaler()
# ----> 3 x_bal=sc.fit_transform(x_bal)
#       4 x_test_bal=sc.transform(x_test_bal)
#       5 x_bal
#
# NameError: name 'x_bal' is not defined

# %%
columns=['age','sex','on_thyroxine','query_on_thyroxine','on_antithyroid_meds','sick','pregnant','thyroid_surgery','I131_treatment','query_hypothyroid','query_hyperthyroid','lithium','goitre','tumor','hypopituitary','psych','TSH_measured','TSH','T3_measured','T3','TT4_measured','TT4','T4U_measured','T4U','FTI_measured','FTI','TBG_measured','TBG','referral_source','target','patient_id']

# %%
x_test_bal=pd.DataFrame(x_test_bal,columns=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f2a7ed159754> in <module>
# ----> 1 x_test_bal=pd.DataFrame(x_test_bal,columns=columns)
#
# NameError: name 'pd' is not defined

# %%
x_bal=pd.DataFrame(x_bal,columns=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-be6c6981e988> in <module>
# ----> 1 x_bal=pd.DataFrame(x_bal,columns=columns)
#
# NameError: name 'x_bal' is not defined

# %%
x_bal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-5fda9bf814cd> in <module>
# ----> 1 x_bal
#
# NameError: name 'x_bal' is not defined

# %%
from sklearn.inspection import permutation_importance
results=permutation_importance(rfr,x_bal,y_bal,scoring='accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-8a0d5f7b50a0> in <module>
#       1 from sklearn.inspection import permutation_importance
# ----> 2 results=permutation_importance(rfr,x_bal,y_bal,scoring='accuracy')
#
# NameError: name 'rfr' is not defined

# %%
feature_importance=['age','sex','on_thyroxine','query_on_throxine','on_antithroid_meds','sick','pregnant','thyroid_surgery']
importance=results.importances_mean
importance=np.sort(importance)
for i,v in enumerate(importance):
  i=feature_importance[i]
  print('feature:'{:20}Score:{}'.format(i,v))
  plt.figure(figsize=(10,10))
  plt.bar(x=feature_importance,height=importance)
  plt.show()
# Out:
#   File "<ipython-input-44-540b12b4239d>", line 6
#     print('feature:'{:20}Score:{}'.format(i,v))
#                     ^
# SyntaxError: invalid syntax

# %%
x.head()
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick pregnant  \
# 18   63   F            t                  f                   f    t        f
# 32   41   M            f                  f                   f    f        f
# 33   71   F            t                  f                   f    f        f
# 39   55   F            t                  f                   f    f        f
# 40   32   F            t                  f                   f    f        f
#
#    thyroid_surgery I131_treatment query_hypothyroid  ... TT4_measured    TT4  \
# 18               f              f                 f  ...            t   48.0
# 32               f              f                 f  ...            t   39.0
# 33               f              f                 f  ...            t  126.0
# 39               f              f                 t  ...            t  136.0
# 40               f              f                 f  ...            t  163.0
#
#    T4U_measured   T4U FTI_measured    FTI TBG_measured  TBG referral_source  \
# 18            t  1.02            t   47.0            f  NaN           other
# 32            t  1.00            t   39.0            f  NaN           other
# 33            t  1.38            t   91.0            f  NaN           other
# 39            t  1.48            t   92.0            f  NaN           other
# 40            t  0.94            t  173.0            f  NaN           other
#
#                      target
# 18  hyperthyroid conditions
# 32            miscellaneous
# 33          binding protein
# 39      replacement therapy
# 40      replacement therapy
#
# [5 rows x 30 columns]

# %%
x_bal.drop([xine','query_'age','sex','on_thyroon_thyroxine','on_antithyroid_meds','sick','pregnant','thyroid_surgery','I131_treatment'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-6879024cdf1c> in <module>
# ----> 1 x_bal.drop(['age','sex','on_thyroxine','query_on_thyroxine','on_antithyroid_meds','sick','pregnant','thyroid_surgery','I131_treatment'])
#
# NameError: name 'x_bal' is not defined

# %%
x_test_bal.drop(['age','sex','on_thyroon_thyroxine','on_antithyroid_meds','sick','pregnant','thyroid_surgery','I131_treatment'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8cc1d2d0be8f> in <module>
# ----> 1 x_test_bal.drop(['age','sex','on_thyroon_thyroxine','on_antithyroid_meds','sick','pregnant','thyroid_surgery','I131_treatment'])
#
# NameError: name 'x_test_bal' is not defined

# %%
x_bal.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-184295172320> in <module>
# ----> 1 x_bal.head()
#
# NameError: name 'x_bal' is not defined
